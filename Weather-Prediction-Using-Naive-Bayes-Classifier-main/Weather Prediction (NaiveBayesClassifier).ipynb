# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv('weather_prediction.csv')
df
# Out:
#      Outlook Temperature Humidity  Windy Play
# 0      Sunny         Hot     High  Flase   No
# 1      Sunny         Hot     High   TRUE   No
# 2   Overcast         Hot     High  Flase  Yes
# 3      Rainy        Mild     High  Flase  Yes
# 4      Rainy        Cool   Normal  Flase  Yes
# 5      Rainy        Cool   Normal   TRUE   No
# 6   Overcast        Cool   Normal   TRUE  Yes
# 7      Sunny        Mild     High  Flase   No
# 8      Sunny        Cool   Normal  Flase  Yes
# 9      Rainy        Mild   Normal  Flase  Yes
# 10     Sunny        Mild   Normal   TRUE  Yes
# 11  Overcast        Mild     High   TRUE  Yes
# 12  Overcast         Hot   Normal  Flase  Yes
# 13     Rainy        Mild     High   TRUE   No

# %%
Numerics = LabelEncoder()

# %%
inputs = df.drop('Play', axis = 'columns')
target = df['Play']
target
# Out:
# 0      No
# 1      No
# 2     Yes
# 3     Yes
# 4     Yes
# 5      No
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13     No
# Name: Play, dtype: object

# %%
inputs['Outlook_n'] = Numerics.fit_transform(inputs['Outlook'])
inputs['Temperature_n'] = Numerics.fit_transform(inputs['Temperature'])
inputs['Humidity_n'] = Numerics.fit_transform(inputs['Humidity'])
inputs['Windy_n'] = Numerics.fit_transform(inputs['Windy'])
inputs
# Out:
#      Outlook Temperature Humidity  Windy  Outlook_n  Temperature_n  \
# 0      Sunny         Hot     High  Flase          2              1
# 1      Sunny         Hot     High   TRUE          2              1
# 2   Overcast         Hot     High  Flase          0              1
# 3      Rainy        Mild     High  Flase          1              2
# 4      Rainy        Cool   Normal  Flase          1              0
# 5      Rainy        Cool   Normal   TRUE          1              0
# 6   Overcast        Cool   Normal   TRUE          0              0
# 7      Sunny        Mild     High  Flase          2              2
# 8      Sunny        Cool   Normal  Flase          2              0
# 9      Rainy        Mild   Normal  Flase          1              2
# 10     Sunny        Mild   Normal   TRUE          2              2
# 11  Overcast        Mild     High   TRUE          0              2
# 12  Overcast         Hot   Normal  Flase          0              1
# 13     Rainy        Mild     High   TRUE          1              2
#
#     Humidity_n  Windy_n
# 0            0        0
# 1            0        1
# 2            0        0
# 3            0        0
# 4            1        0
# 5            1        1
# 6            1        1
# 7            0        0
# 8            1        0
# 9            1        0
# 10           1        1
# 11           0        1
# 12           1        0
# 13           0        1

# %%
inputs_n = inputs.drop(['Outlook', 'Temperature', 'Humidity', 'Windy'], axis = 'columns')
inputs_n
# Out:
#     Outlook_n  Temperature_n  Humidity_n  Windy_n
# 0           2              1           0        0
# 1           2              1           0        1
# 2           0              1           0        0
# 3           1              2           0        0
# 4           1              0           1        0
# 5           1              0           1        1
# 6           0              0           1        1
# 7           2              2           0        0
# 8           2              0           1        0
# 9           1              2           1        0
# 10          2              2           1        1
# 11          0              2           0        1
# 12          0              1           1        0
# 13          1              2           0        1

# %%
Classifier = GaussianNB()
Classifier.fit(inputs_n,target)
# Out:
# GaussianNB()

# %%
Classifier.score(inputs_n,target)
# Out:
# 0.9285714285714286

# %%
Classifier.predict([[1, 1, 0, 0]])
# Out:
# C:\Users\Kusuma N\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype='<U3')

# %%
Classifier.predict([[1,1,0,1]])
# Out:
# C:\Users\Rakshith L\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['No'], dtype='<U3')
